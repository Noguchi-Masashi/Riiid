# %% [markdown]
# # 各種ユーザーログ
# ## 過去N問の正答率
#
# ## 過去N問のうち同じパートでの正答率
#
# メモリの関係で過去N問だけの集計にした。
#
# 800問に伸ばしてもたいして精度変わらなかったが無限にログ取ったら変わったりしたのだろうか？

# %%
import cudf
import pandas as pd
print('cudf_version: ', cudf.__version__)
print('pd_version: ', pd.__version__)
# Out:
# cudf_version:  21.10.01
# pd_version:  1.3.5

# %%
import pandas as pd
import numpy as np
import gc
from sklearn.metrics import roc_auc_score
from collections import defaultdict
from tqdm.notebook import tqdm
import lightgbm as lgb

# %% [markdown]
# ## pandasの場合

# %%
# %%time
validaten_flg = True
if validaten_flg:
    data =  cudf.from_pandas(pd.read_pickle('../input/riiid-cross-validation-files/cv1_train.pickle'))
else:
    data = cudf.read_csv("../input/riiid-test-answer-prediction/train.csv")

print("Train size:", data.shape)
# Out:
# Train size: (98730332, 13)
# CPU times: user 976 ms, sys: 2.85 s, total: 3.83 s
# Wall time: 3.84 s

# %%
data.groupby('user_id').shift(1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /tmp/ipykernel_695/957190674.py in <module>
# ----> 1 data.groupby('user_id').shift(1)
#
# /opt/conda/lib/python3.7/site-packages/cudf/core/groupby/groupby.py in shift(self, periods, freq, axis, fill_value)
#    1042             *self._groupby.shift(Table(value_columns), periods, fill_value)
#    1043         )
# -> 1044         result = self._mimic_pandas_order(result)
#    1045         return result._copy_type_metadata(value_columns)
#    1046
#
# /opt/conda/lib/python3.7/site-packages/cudf/core/groupby/groupby.py in _mimic_pandas_order(self, result)
#    1056         )
#    1057         gather_map = order["sorted_order_column"].argsort()
# -> 1058         result = result.take(gather_map)
#    1059         result.index = self.obj.index
#    1060         return result
#
# /opt/conda/lib/python3.7/site-packages/cudf/core/dataframe.py in take(self, positions, keep_index)
#    3224         if is_bool_dtype(positions):
#    3225             return self._apply_boolean_mask(positions)
# -> 3226         out = self._gather(positions, keep_index=keep_index)
#    3227         out.columns = self.columns
#    3228         return out
#
# /opt/conda/lib/python3.7/site-packages/cudf/core/frame.py in _gather(self, gather_map, keep_index, nullify)
#     544                 as_column(gather_map),
#     545                 keep_index=keep_index,
# --> 546                 nullify=nullify,
#     547             )
#     548         )
#
# cudf/_lib/copying.pyx in cudf._lib.copying.gather()
#
# MemoryError: std::bad_alloc: CUDA error at: /opt/conda/include/rmm/mr/device/cuda_memory_resource.hpp:70: cudaErrorMemoryAllocation out of memory

# %%
data_pdf = data.query('user_answer != -1').to_pandas().groupby('content_id')['user_answer'].value_counts(normalize=True)

# %%
data_gdf = cudf.Series.from_pandas(data_pdf)
data_gdf
# Out:
# content_id  user_answer
# 0           0              0.907334
#             1              0.049727
#             2              0.030544
#             3              0.012395
# 1           1              0.890571
#                              ...
# 13521       3              0.012453
# 13522       3              0.909887
#             1              0.048811
#             2              0.032541
#             0              0.008761
# Name: user_answer, Length: 52050, dtype: float64

# %%
gdf_user_answer = data_gdf.rename('user_answer_rate').reset_index()
gdf_user_answer
# Out:
#        content_id  user_answer  user_answer_rate
# 0               0            0          0.907334
# 1               0            1          0.049727
# 2               0            2          0.030544
# 3               0            3          0.012395
# 4               1            1          0.890571
# ...           ...          ...               ...
# 52045       13521            3          0.012453
# 52046       13522            3          0.909887
# 52047       13522            1          0.048811
# 52048       13522            2          0.032541
# 52049       13522            0          0.008761
#
# [52050 rows x 3 columns]

# %%
data_merge = cudf.merge(data, gdf_user_answer, on=['content_id','user_answer'], how='left')
data_merge
# Out:
#             row_id    timestamp     user_id  content_id  content_type_id  \
# 0         43357222      2660812   918309463        2052                0
# 1         43357223      2660812   918309463        2051                0
# 2         10405786    150097537   226364065        7862                0
# 3         60610523       824690  1286426216         559                0
# 4         67030152    265484710  1424896302        2595                0
# ...            ...          ...         ...         ...              ...
# 98730327  90430642  15293028075  1920242653        1309                0
# 98730328  28719730   3113539480   613867353        4417                0
# 98730329  42136729   3159622708   893296561        5679                0
# 98730330    209682   9702810145     4222121        7898                0
# 98730331  34780088    352380504   743740413       11254                0
#
#           task_container_id  user_answer  answered_correctly  \
# 0                        68            1                   1
# 1                        68            2                   1
# 2                       355            1                   1
# 3                        29            3                   1
# 4                        46            2                   0
# ...                     ...          ...                 ...
# 98730327               5413            1                   1
# 98730328                882            1                   0
# 98730329                584            1                   0
# 98730330                324            2                   1
# 98730331                268            3                   1
#
#          prior_question_elapsed_time prior_question_had_explanation  \
# 0                            22333.0                          False
# 1                            22333.0                          False
# 2                            20000.0                           True
# 3                            17000.0                           True
# 4                            12000.0                           True
# ...                              ...                            ...
# 98730327                     18000.0                           True
# 98730328                     13000.0                           True
# 98730329                      1000.0                           True
# 98730330                     53600.0                           True
# 98730331                     63000.0                           True
#
#           max_time_stamp  rand_time_stamp  viretual_time_stamp  \
# 0             3213491466        280812803            283473615
# 1             3213491466        280812803            283473615
# 2            32007438472        133378842            283476379
# 3                 906141        282660684            283485374
# 4             1222216830         18007988            283492698
# ...                  ...              ...                  ...
# 98730327     15732999210      66957716406          82250744481
# 98730328      4614454983      79137207687          82250747167
# 98730329      5227351169      79091124634          82250747342
# 98730330     12375567057      72547937929          82250748074
# 98730331      2733984189      81898367603          82250748107
#
#           user_answer_rate
# 0                 0.821034
# 1                 0.745510
# 2                 0.980425
# 3                 0.695524
# 4                 0.080073
# ...                    ...
# 98730327          0.421801
# 98730328          0.343949
# 98730329          0.055309
# 98730330          0.543301
# 98730331          0.591104
#
# [98730332 rows x 14 columns]

# %%
import pickle

def pickle_dump(obj, path):
    with open(path, mode='wb') as f:
        pickle.dump(obj,f)

if validaten_flg:
    pickle_dump(gdf_user_answer.to_pandas(), '../input/my_validaten_datasets/user_answer_rate_cv1.pickle')
else:
    gdf_user_answer.to_csv('../input/user_answer_rate.csv', index=False)

# %%
# data_merge.to_pandas().to_csv('../input/all_train.csv', index=False)
